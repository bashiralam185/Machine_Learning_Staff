# %%
# Importing the numpy module
import numpy as np


# creating 
X = np.arange(-210, 210, 3) 
y = np.arange(-200, 220, 3)

# %%
# printing the shape 
X.shape, y.shape
# Out:
# ((140,), (140,))

# %%
# importing the matplotlib module
import matplotlib.pyplot as plt

# fixing the size of the plot
plt.figure( figsize = (12,6))

# plotting scattered plot
plt.scatter(X, y, label = 'Dataset')
plt.legend()
plt.show()

# %%
# Splitting the data into testinga nd training parts
X_train = X[:110]
y_train = y[:110]
X_test = X[110:]
y_test = y[110:]
len(X_train), len(X_test)
# Out:
# (110, 30)

# %%
# size of the plot
plt.figure( figsize = (12,6))

# plotting training and testing parts
plt.scatter(X_train, y_train, c='b', label = 'Training data')
plt.scatter(X_test, y_test, c='g', label='Testing data')
plt.legend()
plt.show()

# %%
# importing tensorflow module
import tensorflow as tf

# creating model and dense layer
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1),
    tf.keras.layers.Dense(1)])

# %%
# compiling the model 
model.compile( loss = tf.keras.losses.mae,
              optimizer = 'adam',
              metrics = ['mae'])

# %%
# tensorflow run model/train model
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 0s 1ms/step - loss: 113.8048 - mae: 113.8048
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 113.4506 - mae: 113.4506
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 113.0918 - mae: 113.0918
# Epoch 4/10
# 4/4 [==============================] - 0s 3ms/step - loss: 112.7538 - mae: 112.7538
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 112.3838 - mae: 112.3838
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 112.0347 - mae: 112.0347
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 111.6885 - mae: 111.6885
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 111.3392 - mae: 111.3392
# Epoch 9/10
# 4/4 [==============================] - 0s 1ms/step - loss: 110.9846 - mae: 110.9846
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 110.6351 - mae: 110.6351

# %%
# Predictions
preds = model.predict(X_test)
# Out:
# WARNING:tensorflow:5 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7feadad5ae50> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 32ms/step

# %%
import sklearn

# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : -70.74820335083031

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# tensorflow run model/train model
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 110.2803 - mae: 110.2803
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 109.9281 - mae: 109.9281
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 109.5716 - mae: 109.5716
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 109.2247 - mae: 109.2247
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 108.8609 - mae: 108.8609
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 108.5030 - mae: 108.5030
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 108.1572 - mae: 108.1572
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 107.8000 - mae: 107.8000
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss:
# Epoch 60/100
# 4/4 [==============================] - 0s 3ms/step - loss: 89.4551 - mae: 89.4551
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 89.1104 - mae: 89.1104
# Epoch 62/100
# 4/4 [==============================] - 0s 2ms/step - loss: 88.7627 - mae: 88.7627
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 88.4182 - mae: 88.4182
# Epoch 64/100
# 4/4 [==============================] - 0s 2ms/step - loss: 88.0541 - mae: 88.0541
# Epoch 65/100
# 4/4 [==============================] - 0s 2ms/step - loss: 87.7135 - mae: 87.7135
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 87.3658 - mae: 87.3658
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 87.0100 - mae: 87.0100
# Epoch 68/100
# 4/4 [==============================] - 0s 2ms/step - loss: 86.6722 - mae: 86.6722
# Epoch 69/100
# 4/4 [==============================] - 0s 2ms/step - loss: 86.3133 - mae: 86.3133
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 85.9741 - mae: 85.9741
# Epoch 71/100
# 4/4 [==============================] - 0s 2ms/step - loss: 85.6147 - mae: 85.6147
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 85.2600 - mae: 85.2600
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 84.9166 - mae: 84.9166
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 84.5657 - mae: 84.5657
# Epoch 75/100
# 4/4 [==============================] - 0s 2ms/step - loss: 84.2094 - mae: 84.2094
# Epoch 76/100
# 4/4 [==============================] - 0s 2ms/step - loss: 83.8544 - mae: 83.8544
# Epoch 77/100
# 4/4 [==============================] - 0s 2ms/step - loss: 83.5070 - mae: 83.5070
# Epoch 78/100
# 4/4 [==============================] - 0s 3ms/step - loss: 83.1409 - mae: 83.1409
# Epoch 79/100
# 4/4 [==============================] - 0s 2ms/step - loss: 82.8057 - mae: 82.8057
# Epoch 80/100
# 4/4 [==============================] - 0s 2ms/step - loss: 82.4376 - mae: 82.4376
# Epoch 81/100
# 4/4 [==============================] - 0s 2ms/step - loss: 82.0894 - mae: 82.0894
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 81.7450 - mae: 81.7450
# Epoch 83/100
# 4/4 [==============================] - 0s 2ms/step - loss: 81.3829 - mae: 81.3829
# Epoch 84/100
# 4/4 [==============================] - 0s 2ms/step - loss: 81.0354 - mae: 81.0354
# Epoch 85/100
# 4/4 [==============================] - 0s 3ms/step - loss: 80.6882 - mae: 80.6882
# Epoch 86/100
# 4/4 [==============================] - 0s 2ms/step - loss: 80.3370 - mae: 80.3370
# Epoch 87/100
# 4/4 [==============================] - 0s 2ms/step - loss: 79.9822 - mae: 79.9822
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 79.6337 - mae: 79.6337
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 79.2959 - mae: 79.2959
# Epoch 90/100
# 4/4 [==============================] - 0s 2ms/step - loss: 78.9442 - mae: 78.9442
# Epoch 91/100
# 4/4 [==============================] - 0s 3ms/step - loss: 78.5947 - mae: 78.5947
# Epoch 92/100
# 4/4 [==============================] - 0s 3ms/step - loss: 78.2411 - mae: 78.2411
# Epoch 93/100
# 4/4 [==============================] - 0s 2ms/step - loss: 77.8943 - mae: 77.8943
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 77.5399 - mae: 77.5399
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 77.2031 - mae: 77.2031
# Epoch 96/100
# 4/4 [==============================] - 0s 2ms/step - loss: 76.8493 - mae: 76.8493
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 76.4979 - mae: 76.4979
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 76.1411 - mae: 76.1411
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 75.7890 - mae: 75.7890
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 75.4339 - mae: 75.4339

# %%
# Predictions
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
import sklearn

# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : -34.517681205498924

# %%
# Initializai
model = tf.keras.Sequential([tf.keras.layers.InputLayer(input_shape=1,),
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 1ms/step - loss: 140.6008 - mae: 140.6008
# Epoch 2/100
# 4/4 [==============================] - 0s 3ms/step - loss: 138.9572 - mae: 138.9572
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 137.4088 - mae: 137.4088
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 135.7731 - mae: 135.7730
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 134.2080 - mae: 134.2080
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 132.5788 - mae: 132.5788
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 131.1144 - mae: 131.1144
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 129.5694 - mae: 129.5694
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 128.0180 - mae: 128.0180
# Epoch 10/100
# 4/4 [==============================] - 0s 3ms/step - loss: 126.5752 - mae: 126.5752
# Epoch 11/100
# 4/4 [==============================] - 0s 2ms/step - loss: 125.0533 - mae: 125.0533
# Epoch 12/100
# 4/4 [==============================] - 0s 2ms/step - loss: 123.6154 - mae: 123.6154
# Epoch 13/100
# 4/4 [==============================] - 0s 2ms/step - loss: 122.0967 - mae: 122.0967
# Epoch 14/100
# 4/4 [==============================] - 0s 2ms/step - loss: 120.6333 - mae: 120.6333
# Epoch 15/100
# 4/4 [==============================] - 0s 2ms/step - loss: 119.1404 - mae: 119.1404
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 117.6850 - mae: 117.6850
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 116.2487 - mae: 116.2487
# Epoch 18/100
# 4/4 [==============================] - 0s 2ms/step - loss: 114.8541 - mae: 114.8541
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 113.4128 - mae: 113.4128
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 112.0703 - mae: 112.0703
# Epoch 21/100
# 4/4 [==============================] - 0s 2ms/step - loss: 110.6649 - mae: 110.6649
# Epoch 22/100
# 4/4 [==============================] - 0s 2ms/step - loss: 109.3389 - mae: 109.3389
# Epoch 23/100
# 4/4 [==============================] - 0s 2ms/step - loss: 107.9700 - mae: 107.9700
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 106.6686 - mae: 106.6686
# Epoch 25/100
# 4/4 [==============================] - 0s 2ms/step - loss: 105.2991 - mae: 105.2991
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 103.9748 - mae: 103.9748
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 102.7135 - mae: 102.7135
# Epoch 28/100
# 4/4 [==============================] - 0s 2ms/step - loss: 101.3257 - mae: 101.3257
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 100.0247 - mae: 100.0247
# Epoch 30/100
# 4/4 [==============================] - 0s 2ms/step - loss: 98.6629 - mae: 98.6629
# Epoch 31/100
# 4/4 [==============================] - 0s 3ms/step - loss: 97.3687 - mae: 97.3686
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 96.0074 - mae: 96.0074
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 94.6630 - mae: 94.6630
# Epoch 34/100
# 4/4 [==============================] - 0s 2ms/step - loss: 93.3609 - mae: 93.3609
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 92.0091 - mae: 92.0091
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 90.7517 - mae: 90.7517
# Epoch 37/100
# 4/4 [==============================] - 0s 3ms/step - loss: 89.4736 - mae: 89.4736
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 88.1484 - mae: 88.1484
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 86.8397 - mae: 86.8397
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss:
# 4/4 [==============================] - 0s 1ms/step - loss: 37.8382 - mae: 37.8382
# Epoch 79/100
# 4/4 [==============================] - 0s 1ms/step - loss: 36.6184 - mae: 36.6184
# Epoch 80/100
# 4/4 [==============================] - 0s 1ms/step - loss: 35.3453 - mae: 35.3453
# Epoch 81/100
# 4/4 [==============================] - 0s 1ms/step - loss: 34.0627 - mae: 34.0627
# Epoch 82/100
# 4/4 [==============================] - 0s 1ms/step - loss: 32.7713 - mae: 32.7713
# Epoch 83/100
# 4/4 [==============================] - 0s 1ms/step - loss: 31.5905 - mae: 31.5905
# Epoch 84/100
# 4/4 [==============================] - 0s 1ms/step - loss: 30.2900 - mae: 30.2900
# Epoch 85/100
# 4/4 [==============================] - 0s 1ms/step - loss: 28.9701 - mae: 28.9701
# Epoch 86/100
# 4/4 [==============================] - 0s 1ms/step - loss: 27.7210 - mae: 27.7210
# Epoch 87/100
# 4/4 [==============================] - 0s 1ms/step - loss: 26.4247 - mae: 26.4247
# Epoch 88/100
# 4/4 [==============================] - 0s 1ms/step - loss: 25.1133 - mae: 25.1133
# Epoch 89/100
# 4/4 [==============================] - 0s 1ms/step - loss: 23.8873 - mae: 23.8873
# Epoch 90/100
# 4/4 [==============================] - 0s 1ms/step - loss: 22.5680 - mae: 22.5680
# Epoch 91/100
# 4/4 [==============================] - 0s 1ms/step - loss: 21.3155 - mae: 21.3155
# Epoch 92/100
# 4/4 [==============================] - 0s 1ms/step - loss: 20.0257 - mae: 20.0257
# Epoch 93/100
# 4/4 [==============================] - 0s 1ms/step - loss: 18.6765 - mae: 18.6765
# Epoch 94/100
# 4/4 [==============================] - 0s 1ms/step - loss: 17.3867 - mae: 17.3867
# Epoch 95/100
# 4/4 [==============================] - 0s 1ms/step - loss: 16.1627 - mae: 16.1627
# Epoch 96/100
# 4/4 [==============================] - 0s 1ms/step - loss: 14.8265 - mae: 14.8265
# Epoch 97/100
# 4/4 [==============================] - 0s 1ms/step - loss: 13.6650 - mae: 13.6650
# Epoch 98/100
# 4/4 [==============================] - 0s 1ms/step - loss: 12.4121 - mae: 12.4121
# Epoch 99/100
# 4/4 [==============================] - 0s 1ms/step - loss: 11.2755 - mae: 11.2755
# Epoch 100/100
# 4/4 [==============================] - 0s 1ms/step - loss: 10.1066 - mae: 10.1066

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 32ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : 0.8679975530330288

# %%
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1,

),
  tf.keras.layers.Dense(15, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 1ms/step - loss: 64.7998 - mae: 64.7998
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 61.0635 - mae: 61.0635
# Epoch 3/100
# 4/4 [==============================] - 0s 3ms/step - loss: 57.3232 - mae: 57.3232
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 53.6044 - mae: 53.6044
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 49.7365 - mae: 49.7365
# Epoch 6/100
# 4/4 [==============================] - 0s 3ms/step - loss: 46.0021 - mae: 46.0021
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 42.1257 - mae: 42.1257
# Epoch 8/100
# 4/4 [==============================] - 0s 3ms/step - loss: 38.1975 - mae: 38.1975
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 34.1563 - mae: 34.1563
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 30.0487 - mae: 30.0487
# Epoch 11/100
# 4/4 [==============================] - 0s 3ms/step - loss: 26.1569 - mae: 26.1569
# Epoch 12/100
# 4/4 [==============================] - 0s 3ms/step - loss: 22.0414 - mae: 22.0414
# Epoch 13/100
# 4/4 [==============================] - 0s 3ms/step - loss: 18.0830 - mae: 18.0830
# Epoch 14/100
# 4/4 [==============================] - 0s 3ms/step - loss: 14.0648 - mae: 14.0648
# Epoch 15/100
# 4/4 [==============================] - 0s 3ms/step - loss: 10.6497 - mae: 10.6497
# Epoch 16/100
# 4/4 [==============================] - 0s 2ms/step - loss: 8.4413 - mae: 8.4413
# Epoch 17/100
# 4/4 [==============================] - 0s 2ms/step - loss: 7.5036 - mae: 7.5036
# Epoch 18/100
# 4/4 [==============================] - 0s 3ms/step - loss: 5.7989 - mae: 5.7989
# Epoch 19/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.1995 - mae: 4.1995
# Epoch 20/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.6008 - mae: 4.6008
# Epoch 21/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.7951 - mae: 4.7951
# Epoch 22/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.5738 - mae: 4.5738
# Epoch 23/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.2983 - mae: 4.2983
# Epoch 24/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.1684 - mae: 4.1684
# Epoch 25/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.1544 - mae: 4.1544
# Epoch 26/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.1672 - mae: 4.1672
# Epoch 27/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.1293 - mae: 4.1293
# Epoch 28/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.0963 - mae: 4.0963
# Epoch 29/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.0570 - mae: 4.0570
# Epoch 30/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.0433 - mae: 4.0433
# Epoch 31/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0557 - mae: 4.0557
# Epoch 32/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0350 - mae: 4.0350
# Epoch 33/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.0351 - mae: 4.0351
# Epoch 34/100
# 4/4 [==============================] - 0s 3ms/step - loss: 4.0299 - mae: 4.0299
# Epoch 35/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0159 - mae: 4.0159
# Epoch 36/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0038 - mae: 4.0038
# Epoch 37/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0280 - mae: 4.0280
# Epoch 38/100
# 4/4 [==============================] - 0s 2ms/step - loss: 4.0191 - mae: 4.0191
# Epoch 39/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9779 - mae: 3.9779
# Epoch 40/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.9516 - mae: 3.9516
# Epoch 41/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9566 - mae: 3.9566
# Epoch 42/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9566 - mae: 3.9566
# Epoch 43/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.9408 - mae: 3.9408
# Epoch 44/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.9368 - mae: 3.9368
# Epoch 45/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9231 - mae: 3.9231
# Epoch 46/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9010 - mae: 3.9010
# Epoch 47/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8982 - mae: 3.8982
# Epoch 48/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8954 - mae: 3.8954
# Epoch 49/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8773 - mae: 3.8773
# Epoch 50/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.9102 - mae: 3.9102
# Epoch 51/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8888 - mae: 3.8888
# Epoch 52/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8427 - mae: 3.8427
# Epoch 53/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8500 - mae: 3.8500
# Epoch 54/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8445 - mae: 3.8445
# Epoch 55/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8196 - mae: 3.8196
# Epoch 56/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8395 - mae: 3.8395
# Epoch 57/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8219 - mae: 3.8219
# Epoch 58/100
# 4/4 [==============================] - 0s 4ms/step - loss: 3.8147 - mae: 3.8147
# Epoch 59/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8045 - mae: 3.8045
# Epoch 60/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.8103 - mae: 3.8103
# Epoch 61/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7931 - mae: 3.7931
# Epoch 62/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.7648 - mae: 3.7648
# Epoch 63/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.7517 - mae: 3.7517
# Epoch 64/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.8068 - mae: 3.8068
# Epoch 65/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.7504 - mae: 3.7504
# Epoch 66/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7546 - mae: 3.7546
# Epoch 67/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.7520 - mae: 3.7520
# Epoch 68/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.7041 - mae: 3.7041
# Epoch 69/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6885 - mae: 3.6885
# Epoch 70/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6769 - mae: 3.6769
# Epoch 71/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6752 - mae: 3.6752
# Epoch 72/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6959 - mae: 3.6959
# Epoch 73/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6671 - mae: 3.6671
# Epoch 74/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6365 - mae: 3.6365
# Epoch 75/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6352 - mae: 3.6352
# Epoch 76/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6416 - mae: 3.6416
# Epoch 77/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6247 - mae: 3.6247
# Epoch 78/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.6089 - mae: 3.6089
# Epoch 79/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6557 - mae: 3.6557
# Epoch 80/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.6142 - mae: 3.6142
# Epoch 81/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5823 - mae: 3.5823
# Epoch 82/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5647 - mae: 3.5647
# Epoch 83/100
# 4/4 [==============================] - 0s 5ms/step - loss: 3.5596 - mae: 3.5596
# Epoch 84/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5347 - mae: 3.5347
# Epoch 85/100
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5414 - mae: 3.5414
# Epoch 86/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.5595 - mae: 3.5595
# Epoch 87/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4898 - mae: 3.4898
# Epoch 88/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5400 - mae: 3.5400
# Epoch 89/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5185 - mae: 3.5185
# Epoch 90/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4669 - mae: 3.4669
# Epoch 91/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.5399 - mae: 3.5399
# Epoch 92/100
# 4/4 [==============================] - 0s 4ms/step - loss: 3.5378 - mae: 3.5378
# Epoch 93/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4579 - mae: 3.4579
# Epoch 94/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.4565 - mae: 3.4565
# Epoch 95/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4590 - mae: 3.4590
# Epoch 96/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4125 - mae: 3.4125
# Epoch 97/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.4066 - mae: 3.4066
# Epoch 98/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.4183 - mae: 3.4183
# Epoch 99/100
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4252 - mae: 3.4252
# Epoch 100/100
# 4/4 [==============================] - 0s 2ms/step - loss: 3.3810 - mae: 3.3810

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : 0.9085007410410029

# %%
from tensorflow import keras

def model_builder(hp):
  model = keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1,

)])
#   model.add(keras.layers.Flatten(input_shape=(28, 28)))

  # Tune the number of units in the first Dense layer
  # Choose an optimal value between 32-512
  hp_units = hp.Int('units', min_value=10, max_value=100, step=5)
  model.add(keras.layers.Dense(units=hp_units, activation='relu'))
  model.add(keras.layers.Dense(1))

#   hp_learning_rate = hp.Choice('learning_rate', values=[1e-2, 1e-3, 1e-4])
  model.compile(optimizer=keras.optimizers.SGD(),
                loss=tf.keras.losses.mae,
                metrics=['mae'])

  return model

# %%
import keras_tuner as kt

# %%
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=50,
                    )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(X_train, y_train, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units')}
""")
# Out:
# INFO:tensorflow:Oracle triggered exit
#
# The hyperparameter search is complete. The optimal number of units in the first densely-connected
# layer is 55

# %%
# impprting the module
import pandas as pd

#importing dataset
House = pd.read_csv('Dushanbe_house.csv')

# heading
House.head()
# Out:
#    Unnamed: 0  number_of_rooms  floor  area   latitude  longitude   price
# 0           0                1      1  58.0  38.585834  68.793715  330000
# 1           1                1     14  68.0  38.522254  68.749918  340000
# 2           2                3      8  50.0        NaN        NaN  700000
# 3           3                3     14  84.0  38.520835  68.747908  700000
# 4           4                3      3  83.0  38.564374  68.739419  415000

# %%
# dropping the column
House.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# removing null avlues
House.dropna(inplace=True)

# %%
House.isnull().sum()
# Out:
# number_of_rooms    0
# floor              0
# area               0
# latitude           0
# longitude          0
# price              0
# dtype: int64

# %%
# shape of dataset
House.shape
# Out:
# (3730, 6)

# %%
# splitting our dataset into independent and dependent variables
x_data = House.drop('price', axis=1)
y_data = House.price

# %%
# importing the module
from sklearn.model_selection import train_test_split

# splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
# fixing random state
tf.random.set_seed(42)

# building the model with hidden layer
model_house = tf.keras.Sequential([
  tf.keras.layers.Dense(15, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# compiling the model
model_house.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])

# Training the model
model_house.fit(X_train, y_train, epochs=100, verbose=0)

# %%
# making predictions
preds_house = model_house.predict(X_test)
# Out:
# 30/30 [==============================] - 0s 5ms/step

# %%
# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house))
# Out:
# R score is : -0.8498295679793813

# %%
# fitting the size of the plot
plt.figure(figsize=(16, 8))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, label="actual values", c='r')
plt.plot([i for i in range(len(y_test))],preds_house, label="Predicted values", c='g')

# showing the plotting
plt.legend()
plt.show()

# %%
# creating a model
model_house1 = tf.keras.Sequential([
  tf.keras.layers.Dense(100, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# compiling the model
model_house1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# train model on 10 epochs
model_house1.fit(X_train, y_train, epochs=10, verbose=0)

# %%
# making predictions
preds_house1 = model_house1.predict(X_test)

from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house1))
# Out:
# 30/30 [==============================] - 1s 3ms/step
# R score is : 0.4282669460341727

# %%
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house6))from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house6))
# Out:
# R score is : 0.3882988903867426

# %%
# fitting the size of the plot
plt.figure(figsize=(16, 8))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, label="actual values", c='r')
plt.plot([i for i in range(len(y_test))],preds_house1, label="Predicted values", c='g')

# showing the plotting
plt.legend()
plt.show()
