# %%
# Importing the numpy module
import numpy as np


# creating 
X = np.arange(-210, 210, 3) 
y = np.arange(-200, 220, 3)

# %%
# printing the shape 
X.shape, y.shape
# Out:
# ((140,), (140,))

# %%
# importing the matplotlib module
import matplotlib.pyplot as plt

# fixing the size of the plot
plt.figure( figsize = (12,6))

# plotting scattered plot
plt.scatter(X, y, label = 'Dataset')
plt.legend()
plt.show()

# %%
# Splitting the data into testinga nd training parts
X_train = X[:110]
y_train = y[:110]
X_test = X[110:]
y_test = y[110:]
len(X_train), len(X_test)
# Out:
# (110, 30)

# %%
# size of the plot
plt.figure( figsize = (12,6))

# plotting training and testing parts
plt.scatter(X_train, y_train, c='b', label = 'Training data')
plt.scatter(X_test, y_test, c='g', label='Testing data')
plt.legend()
plt.show()

# %%
# importing tensorflow module
import tensorflow as tf

# creating model and dense layer
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1),
    tf.keras.layers.Dense(1)])
# Out:
# 2022-06-07 16:54:56.549276: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-06-07 16:54:56.549386: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-06-07 16:55:26.244784: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-06-07 16:55:26.244818: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-06-07 16:55:26.244843: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (UCA-Nar): /proc/driver/nvidia/version does not exist
# ...

# %%
# compiling the model 
model.compile( loss = tf.keras.losses.mae,
              optimizer = 'adam',
              metrics = ['mae'])

# %%
# tensorflow run model/train model
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=10)
# Out:
# Epoch 1/10
# 4/4 [==============================] - 1s 6ms/step - loss: 155.8499 - mae: 155.8499
# Epoch 2/10
# 4/4 [==============================] - 0s 2ms/step - loss: 155.4960 - mae: 155.4960
# Epoch 3/10
# 4/4 [==============================] - 0s 2ms/step - loss: 155.1399 - mae: 155.1399
# Epoch 4/10
# 4/4 [==============================] - 0s 2ms/step - loss: 154.7948 - mae: 154.7948
# Epoch 5/10
# 4/4 [==============================] - 0s 2ms/step - loss: 154.4354 - mae: 154.4354
# Epoch 6/10
# 4/4 [==============================] - 0s 2ms/step - loss: 154.0801 - mae: 154.0801
# Epoch 7/10
# 4/4 [==============================] - 0s 2ms/step - loss: 153.7164 - mae: 153.7164
# Epoch 8/10
# 4/4 [==============================] - 0s 2ms/step - loss: 153.3725 - mae: 153.3725
# Epoch 9/10
# 4/4 [==============================] - 0s 2ms/step - loss: 153.0201 - mae: 153.0201
# Epoch 10/10
# 4/4 [==============================] - 0s 2ms/step - loss: 152.6656 - mae: 152.6656

# %%
# Predictions
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 1s 774ms/step

# %%
import sklearn

# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : -130.88912542227948

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# tensorflow run model/train model
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 152.3014 - mae: 152.3014
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 151.9572 - mae: 151.9572
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 151.6048 - mae: 151.6048
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 151.2405 - mae: 151.2405
# Epoch 5/100
# 4/4 [==============================] - 0s 3ms/step - loss: 150.8921 - mae: 150.8921
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 150.5337 - mae: 150.5337
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 150.1834 - mae: 150.1834
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 149.8250 - mae: 149.8250
# Epoch 9/100
# 4/4 [==============================] - 0s 3ms/step - loss: 149.4680 - mae: 149.4680
# Epoch 10/100
# ...

# %%
# Predictions
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 19ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
import sklearn

# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : -79.26336297781381

# %%
# Initializai
model = tf.keras.Sequential([tf.keras.layers.InputLayer(input_shape=1,),
  tf.keras.layers.Dense(10, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 2ms/step - loss: 44.7536 - mae: 44.7536
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 43.5786 - mae: 43.5786
# Epoch 3/100
# 4/4 [==============================] - 0s 1ms/step - loss: 42.3944 - mae: 42.3944
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 41.1653 - mae: 41.1653
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 39.9776 - mae: 39.9776
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 38.7521 - mae: 38.7521
# Epoch 7/100
# 4/4 [==============================] - 0s 2ms/step - loss: 37.5094 - mae: 37.5094
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 36.2359 - mae: 36.2359
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 35.0460 - mae: 35.0460
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 33.7542 - mae: 33.7542
# Epoch 11/100
# ...

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 39ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : 0.8821481278145455

# %%
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1,

),
  tf.keras.layers.Dense(15, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=100)
# Out:
# Epoch 1/100
# 4/4 [==============================] - 0s 1ms/step - loss: 20.9235 - mae: 20.9235
# Epoch 2/100
# 4/4 [==============================] - 0s 2ms/step - loss: 19.3682 - mae: 19.3682
# Epoch 3/100
# 4/4 [==============================] - 0s 2ms/step - loss: 17.8358 - mae: 17.8358
# Epoch 4/100
# 4/4 [==============================] - 0s 2ms/step - loss: 16.3642 - mae: 16.3642
# Epoch 5/100
# 4/4 [==============================] - 0s 2ms/step - loss: 15.0820 - mae: 15.0820
# Epoch 6/100
# 4/4 [==============================] - 0s 2ms/step - loss: 13.7757 - mae: 13.7757
# Epoch 7/100
# 4/4 [==============================] - 0s 3ms/step - loss: 12.6512 - mae: 12.6512
# Epoch 8/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.7147 - mae: 11.7147
# Epoch 9/100
# 4/4 [==============================] - 0s 2ms/step - loss: 11.0042 - mae: 11.0042
# Epoch 10/100
# 4/4 [==============================] - 0s 2ms/step - loss: 10.5568 - mae: 10.5568
# Epoch 11/100
# ...

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 41ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : 0.8999663416272187

# %%
# importing required modules
from tensorflow import keras
import keras_tuner as kt


# user define function
def model_builder(hp):
    
    # first layer of the model
    model = keras.Sequential([tf.keras.layers.InputLayer(input_shape=1,)])

    # specifying the min and max nodes for hidden layer
    hp_units = hp.Int('units', min_value=10, max_value=100)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    # output layer
    model.add(keras.layers.Dense(1))

    #compiling the model
    model.compile(optimizer=keras.optimizers.SGD(),
                    loss=tf.keras.losses.mae,
                    metrics=['mae'])

    return model

# %%
# initializing the tunner 
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=200,
                    )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
# Early stopping in keras
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4)

# %%
# Seaching the tunner 
tuner.search(X, y, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# printing the optimal number of nodes 
print('The optimal number of nodes in the hidden layer is: ', best_hps.get('units'))
# Out:
# INFO:tensorflow:Oracle triggered exit
# The optimal number of nodes in the hidden layer is:  55

# %%
# creating model with the optimum parameters
model = tuner.hypermodel.build(best_hps)

# fixed max max epohcs to 100
Training_model = model.fit(X, y, epochs=300, validation_split=0.2)

# val_loss 
val_acc_per_epoch = Training_model.history['val_loss']

# printing optimum eppoc
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch:',  best_epoch)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 0s 40ms/step - loss: 64.4943 - mae: 64.4943 - val_loss: 34.8216 - val_mae: 34.8216
# Epoch 2/300
# 4/4 [==============================] - 0s 11ms/step - loss: 48.2300 - mae: 48.2300 - val_loss: 11.1381 - val_mae: 11.1381
# Epoch 3/300
# 4/4 [==============================] - 0s 12ms/step - loss: 48.0393 - mae: 48.0393 - val_loss: 33.8268 - val_mae: 33.8268
# Epoch 4/300
# 4/4 [==============================] - 0s 11ms/step - loss: 47.7932 - mae: 47.7932 - val_loss: 36.1509 - val_mae: 36.1509
# Epoch 5/300
# 4/4 [==============================] - 0s 12ms/step - loss: 40.4282 - mae: 40.4282 - val_loss: 50.9165 - val_mae: 50.9165
# Epoch 6/300
# 4/4 [==============================] - 0s 12ms/step - loss: 47.4481 - mae: 47.4481 - val_loss: 33.6076 - val_mae: 33.6076
# Epoch 7/300
# 4/4 [==============================] - 0s 11ms/step - loss: 46.5392 - mae: 46.5392 - val_loss: 1.2707 - val_mae: 1.2707
# Epoch 8/300
# ...

# %%
# Creating modele complinin
model = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=1,),
  tf.keras.layers.Dense(55, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# Complining the model
model.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])

# training the model on optimum epochs
model.fit(tf.expand_dims(X_train, axis=-1), y_train, epochs=170)
# Out:
# Epoch 1/170
# 4/4 [==============================] - 0s 2ms/step - loss: 95.2998 - mae: 95.2998
# Epoch 2/170
# 4/4 [==============================] - 0s 2ms/step - loss: 92.6647 - mae: 92.6647
# Epoch 3/170
# 4/4 [==============================] - 0s 3ms/step - loss: 90.1408 - mae: 90.1408
# Epoch 4/170
# 4/4 [==============================] - 0s 3ms/step - loss: 87.6642 - mae: 87.6642
# Epoch 5/170
# 4/4 [==============================] - 0s 3ms/step - loss: 85.0776 - mae: 85.0776
# Epoch 6/170
# 4/4 [==============================] - 0s 3ms/step - loss: 82.5449 - mae: 82.5449
# Epoch 7/170
# 4/4 [==============================] - 0s 3ms/step - loss: 79.8946 - mae: 79.8946
# Epoch 8/170
# 4/4 [==============================] - 0s 3ms/step - loss: 77.3356 - mae: 77.3356
# Epoch 9/170
# 4/4 [==============================] - 0s 3ms/step - loss: 74.7566 - mae: 74.7566
# Epoch 10/170
# 4/4 [==============================] - 0s 2ms/step - loss: 72.0130 - mae: 72.0130
# Epoch 11/170
# ...

# %%
preds = model.predict(X_test)
# Out:
# 1/1 [==============================] - 0s 53ms/step

# %%
# size of the plot
plt.figure(figsize=(12,6))

# plotting the garah
plt.scatter(X_train, y_train, c="b", label="Training data")
plt.scatter(X_test, y_test, c="g", label="Testing data")
plt.scatter(X_test, preds, c="r", label="Predictions")
plt.legend()
plt.show()

# %%
# Evaluating the model
print('R score is :', r2_score(y_test, preds))
# Out:
# R score is : 0.9423982958889141

# %%
# impprting the module
import pandas as pd

#importing dataset
House = pd.read_csv('Dushanbe_house.csv')

# heading
House.head()
# Out:
#    Unnamed: 0  number_of_rooms  floor  area   latitude  longitude   price
# 0           0                1      1  58.0  38.585834  68.793715  330000
# 1           1                1     14  68.0  38.522254  68.749918  340000
# 2           2                3      8  50.0        NaN        NaN  700000
# 3           3                3     14  84.0  38.520835  68.747908  700000
# 4           4                3      3  83.0  38.564374  68.739419  415000

# %%
# dropping the column
House.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# removing null avlues
House.dropna(inplace=True)

# %%
House.isnull().sum()
# Out:
# number_of_rooms    0
# floor              0
# area               0
# latitude           0
# longitude          0
# price              0
# dtype: int64

# %%
# shape of dataset
House.shape
# Out:
# (3730, 6)

# %%
# splitting our dataset into independent and dependent variables
x_data = House.drop('price', axis=1)
y_data = House.price

# %%
# importing the module
from sklearn.model_selection import train_test_split

# splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
# fixing random state
tf.random.set_seed(42)

# building the model with hidden layer
model_house = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=5,),
  tf.keras.layers.Dense(100, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# compiling the model
model_house.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])

# Training the model
model_house.fit(X_train, y_train, epochs=10, verbose=0)

# %%
# making predictions
preds_house = model_house.predict(X_test)
# Out:
# 30/30 [==============================] - 0s 824us/step

# %%
# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house))
# Out:
# R score is : -2.2360184694378

# %%
# fitting the size of the plot
plt.figure(figsize=(16, 8))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, label="actual values", c='r')
plt.plot([i for i in range(len(y_test))],preds_house, label="Predicted values", c='g')

# showing the plotting
plt.legend()
plt.show()

# %%
# creating deep neural network
model_house1 = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=5,),
  tf.keras.layers.Dense(100, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(1)
])

# compiling the deep neural network
model_house1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.SGD(),
                metrics=['mae'])

# train deep learning model on 10 epochs
model_house1.fit(X_train, y_train, epochs=10, verbose=0)

# %%
# making predictions
preds_house1 = model_house1.predict(X_test)

from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house1))
# Out:
# 30/30 [==============================] - 0s 817us/step
# R score is : -2.6218228704309188

# %%
# fitting the size of the plot
plt.figure(figsize=(16, 8))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, label="actual values", c='r')
plt.plot([i for i in range(len(y_test))],preds_house1, label="Predicted values", c='g')

# showing the plotting
plt.legend()
plt.show()

# %%
# user define function
def model_builder(hp):
    
    # first layer of the model
    model = keras.Sequential([tf.keras.layers.InputLayer(input_shape=5,)])

    # specifying the min and max nodes for hidden layer
    hp_units = hp.Int('units', min_value=10, max_value=100)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    # output layer
    model.add(keras.layers.Dense(1))

    #compiling the model
    model.compile(optimizer=keras.optimizers.SGD(),
                    loss=tf.keras.losses.mae,
                    metrics=['mae'])

    return model

# %%
# initializing the tunner 
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=200,
                    )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4)

# %%
# Seaching the tunner 
tuner.search(x_data, y_data, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# printing the optimal number of nodes 
print('The optimal number of node in the hidden layer is: ', best_hps.get('units'))
# Out:
# INFO:tensorflow:Oracle triggered exit
# The optimal number of node in the hidden layer is:  55
