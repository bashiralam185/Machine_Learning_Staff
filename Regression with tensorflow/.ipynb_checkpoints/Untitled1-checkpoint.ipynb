# %%
# impprting the module
import pandas as pd

#importing dataset
House = pd.read_csv('Dushanbe_house.csv')

# heading
House.head()
# Out:
#    Unnamed: 0  number_of_rooms  floor  area   latitude  longitude   price
# 0           0                1      1  58.0  38.585834  68.793715  330000
# 1           1                1     14  68.0  38.522254  68.749918  340000
# 2           2                3      8  50.0        NaN        NaN  700000
# 3           3                3     14  84.0  38.520835  68.747908  700000
# 4           4                3      3  83.0  38.564374  68.739419  415000

# %%
# dropping the column
House.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# removing null avlues
House.dropna(inplace=True)

# %%
# splitting our dataset into independent and dependent variables
x_data = House.drop('price', axis=1)
y_data = House.price

# %%
# importing the module
from sklearn.model_selection import train_test_split

# splitting the dataset
X_train, X_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.25, random_state = 0)

# %%
# user define function
def model_builder(hp):
    
    # first layer of the model
    model = keras.Sequential([tf.keras.layers.InputLayer(input_shape=5,)])

    # specifying the min and max nodes for hidden layer
    hp_units = hp.Int('units', min_value=10, max_value=100)
    model.add(keras.layers.Dense(units=hp_units, activation='relu'))
    
    # output layer
    model.add(keras.layers.Dense(1))

    #compiling the model
    model.compile(optimizer=keras.optimizers.SGD(),
                    loss=tf.keras.losses.mae,
                    metrics=['mae'])

    return model

# %%
# importing required modules
from tensorflow import keras
import keras_tuner as kt
import tensorflow as tf
# initializing the tunner 
tuner = kt.Hyperband(model_builder,
                     objective='val_loss',
                     max_epochs=200,
                    )
# Out:
# INFO:tensorflow:Reloading Oracle from existing project ./untitled_project/oracle.json
# INFO:tensorflow:Reloading Tuner from ./untitled_project/tuner0.json

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience = 4)

# %%
# Seaching the tunner 
tuner.search(x_data, y_data, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# printing the optimal number of nodes 
print('The optimal number of node in the hidden layer is: ', best_hps.get('units'))
# Out:
# INFO:tensorflow:Oracle triggered exit
# The optimal number of node in the hidden layer is:  55

# %%
# creating model with the optimum parameters
model = tuner.hypermodel.build(best_hps)

# fixed max max epohcs to 300
Training_model = model.fit(x_data, y_data, epochs=100, validation_split=0.2)

# val_loss 
val_acc_per_epoch = Training_model.history['val_loss']

# printing optimum eppoc
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch:',  best_epoch)
# Out:
# Epoch 1/100
# 94/94 [==============================] - 1s 3ms/step - loss: 491690.1562 - mae: 491690.1562 - val_loss: 546951.3125 - val_mae: 546951.3125
# Epoch 2/100
# 94/94 [==============================] - 0s 2ms/step - loss: 525737.1250 - mae: 525737.1250 - val_loss: 546948.1250 - val_mae: 546948.1250
# Epoch 3/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531853.8750 - mae: 531853.8750 - val_loss: 546947.1875 - val_mae: 546947.1875
# Epoch 4/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531852.8125 - mae: 531852.8125 - val_loss: 546946.2500 - val_mae: 546946.2500
# Epoch 5/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531851.8125 - mae: 531851.8125 - val_loss: 546945.3125 - val_mae: 546945.3125
# Epoch 6/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531851.1250 - mae: 531851.1250 - val_loss: 546944.4375 - val_mae: 546944.4375
# Epoch 7/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531850.0625 - mae: 531850.0625 - val_loss: 546943.4375 - val_mae: 546943.4375
# Epoch 8/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531849.1875 - mae: 531849.1875 - val_loss: 546942.5625 - val_mae: 546942.5625
# Epoch 9/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531848.1250 - mae: 531848.1250 - val_loss: 546941.6250 - val_mae: 546941.6250
# Epoch 10/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531847.3125 - mae: 531847.3125 - val_loss: 546940.6250 - val_mae: 546940.6250
# Epoch 11/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531846.3750 - mae: 531846.3750 - val_loss: 546939.6875 - val_mae: 546939.6875
# Epoch 12/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531845.2500 - mae: 531845.2500 - val_loss: 546938.6875 - val_mae: 546938.6875
# Epoch 13/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531844.3125 - mae: 531844.3125 - val_loss: 546937.8125 - val_mae: 546937.8125
# Epoch 14/100
# 94/94 [==============================] - 0s 2ms/step - loss: 
100
# 94/94 [==============================] - 0s 2ms/step - loss: 531783.1875 - mae: 531783.1875 - val_loss: 546876.6875 - val_mae: 546876.6875
# Epoch 79/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531782.3750 - mae: 531782.3750 - val_loss: 546875.7500 - val_mae: 546875.7500
# Epoch 80/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531781.5000 - mae: 531781.5000 - val_loss: 546874.8125 - val_mae: 546874.8125
# Epoch 81/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531780.5625 - mae: 531780.5625 - val_loss: 546873.9375 - val_mae: 546873.9375
# Epoch 82/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531779.6250 - mae: 531779.6250 - val_loss: 546872.8750 - val_mae: 546872.8750
# Epoch 83/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531778.6875 - mae: 531778.6875 - val_loss: 546872.0000 - val_mae: 546872.0000
# Epoch 84/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531777.8125 - mae: 531777.8125 - val_loss: 546871.1250 - val_mae: 546871.1250
# Epoch 85/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531776.7500 - mae: 531776.7500 - val_loss: 546870.0625 - val_mae: 546870.0625
# Epoch 86/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531775.8125 - mae: 531775.8125 - val_loss: 546869.1250 - val_mae: 546869.1250
# Epoch 87/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531774.8750 - mae: 531774.8750 - val_loss: 546868.1875 - val_mae: 546868.1875
# Epoch 88/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531773.8750 - mae: 531773.8750 - val_loss: 546867.3750 - val_mae: 546867.3750
# Epoch 89/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531772.9375 - mae: 531772.9375 - val_loss: 546866.3750 - val_mae: 546866.3750
# Epoch 90/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531772.1250 - mae: 531772.1250 - val_loss: 546865.4375 - val_mae: 546865.4375
# Epoch 91/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531771.1250 - mae: 531771.1250 - val_loss: 546864.5625 - val_mae: 546864.5625
# Epoch 92/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531770.3125 - mae: 531770.3125 - val_loss: 546863.5625 - val_mae: 546863.5625
# Epoch 93/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531769.1250 - mae: 531769.1250 - val_loss: 546862.5625 - val_mae: 546862.5625
# Epoch 94/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531768.4375 - mae: 531768.4375 - val_loss: 546861.6250 - val_mae: 546861.6250
# Epoch 95/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531767.3125 - mae: 531767.3125 - val_loss: 546860.6875 - val_mae: 546860.6875
# Epoch 96/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531766.3750 - mae: 531766.3750 - val_loss: 546859.7500 - val_mae: 546859.7500
# Epoch 97/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531765.4375 - mae: 531765.4375 - val_loss: 546858.8125 - val_mae: 546858.8125
# Epoch 98/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531764.5625 - mae: 531764.5625 - val_loss: 546857.9375 - val_mae: 546857.9375
# Epoch 99/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531763.6250 - mae: 531763.6250 - val_loss: 546856.8750 - val_mae: 546856.8750
# Epoch 100/100
# 94/94 [==============================] - 0s 2ms/step - loss: 531762.5000 - mae: 531762.5000 - val_loss: 546856.0000 - val_mae: 546856.0000
# Best epoch: 1

# %%
# fixing random state
tf.random.set_seed(42)

# building the model with hidden layer
model_house = tf.keras.Sequential([tf.keras.layers.InputLayer(
    input_shape=5,),
  tf.keras.layers.Dense(15, activation = tf.keras.activations.relu),
  tf.keras.layers.Dense(25, activation = tf.keras.activations.relu),
                                   
  tf.keras.layers.Dense(1)
])

# compiling the model
model_house.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])

# Training the model
model_house.fit(X_train, y_train, epochs=100, verbose=0)

# %%
preds_house = model_house.predict(X_test)
# Out:
# 30/30 [==============================] - 0s 1ms/step

# %%
# Importing the required module
from sklearn.metrics import r2_score

# Evaluating the model
print('R score is :', r2_score(y_test, preds_house))
# Out:
# R score is : 0.5800100862264927

# %%
import matplotlib.pyplot as plt

# %%
# fitting the size of the plot
plt.figure(figsize=(16, 8))

# plotting the graphs
plt.plot([i for i in range(len(y_test))],y_test, label="actual values", c='r')
plt.plot([i for i in range(len(y_test))],preds_house, label="Predicted values", c='g')

# showing the plotting
plt.legend()
plt.show()
