# %%
# importing pandas module
import pandas as pd

# importing the dataset
data = pd.read_csv('house.csv')

# printing few rows of the dataset
data.head()
# Out:
#    number_of_rooms  floor  area   latitude  longitude   price
# 0                1      1  58.0  38.585834  68.793715  330000
# 1                1     14  68.0  38.522254  68.749918  340000
# 2                3      8  50.0        NaN        NaN  700000
# 3                3     14  84.0  38.520835  68.747908  700000
# 4                3      3  83.0  38.564374  68.739419  415000

# %%
# removing null values
data.dropna(axis=0, inplace=True)

# %%
# using info method to get details
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3730 entries, 0 to 5572
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   number_of_rooms  3730 non-null   int64
#  1   floor            3730 non-null   int64
#  2   area             3730 non-null   float64
#  3   latitude         3730 non-null   float64
#  4   longitude        3730 non-null   float64
#  5   price            3730 non-null   int64
# dtypes: float64(3), int64(3)
# memory usage: 204.0 KB

# %%
# describe function of pandas
data.describe()
# Out:
#        number_of_rooms        floor         area     latitude    longitude  \
# count      3730.000000  3730.000000  3730.000000  3730.000000  3730.000000
# mean          2.319035     6.553351    72.179893    38.553452    68.768399
# std           1.036780     4.355972    33.330143     0.030199     0.056909
# min           1.000000     0.000000    16.000000    37.511664    68.667721
# 25%           2.000000     3.000000    50.000000    38.530576    68.739065
# 50%           2.000000     5.000000    65.000000    38.560678    68.761022
# 75%           3.000000    10.000000    84.000000    38.572482    68.789177
# max           6.000000    20.000000   370.000000    38.615876    71.509309
#
#               price
# count  3.730000e+03
# mean   5.348747e+05
# std    4.163996e+05
# min    4.500000e+02
# 25%    3.200000e+05
# 50%    4.500000e+05
# 75%    6.300000e+05
# max    8.814000e+06

# %%
# plotting line plots using pandas
data['price'].plot(figsize=(10, 6), c='m')
# Out:
# <AxesSubplot:>

# %%
# plotting multi-line plots uing pandas
data.drop('price', axis=1).plot(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
# plotting multi-line plots uing pandas
data.drop('price', axis=1).plot(figsize=(10, 6), subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>,
#        <AxesSubplot:>], dtype=object)

# %%
data['latitude'].plot(x="Rank", y=["P25th", "Median", "P75th"])
# Out:
# <AxesSubplot:>

# %%
# taking 10% of the data randomly
dataset = data.sample(frac = 0.009)

# plotting bar charts
dataset['floor'].plot(kind='bar', figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
# copying the dataset
bar_plot = dataset.copy()

# dropping unwanted variables
bar_plot.drop('area', axis=1, inplace=True)
bar_plot.drop('latitude', axis=1, inplace=True)
bar_plot.drop('longitude', axis=1, inplace=True)
bar_plot.drop('price', axis=1, inplace=True)

# plotting the bar chart
bar_plot.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
# plotting the bar chart
bar_plot.plot.barh(stacked=True, figsize=(6, 8))
# Out:
# <AxesSubplot:>

# %%
# copying the dataset
hist_plot =bar_plot.copy()

# plotting histogram chart
hist_plot.plot.hist(figsize=(10, 6))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plotting histogram chart
hist_plot.plot.hist(figsize=(10, 6), stacked=True)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# plottig comulative histogram
hist_plot.plot.hist(orientation="horizontal", cumulative=True, figsize=(10, 6))

# %%
# histogram for each of the column
dataset.diff().hist(figsize=(10, 6))
# Out:
# array([[<AxesSubplot:title={'center':'number_of_rooms'}>,
#         <AxesSubplot:title={'center':'floor'}>],
#        [<AxesSubplot:title={'center':'area'}>,
#         <AxesSubplot:title={'center':'latitude'}>],
#        [<AxesSubplot:title={'center':'longitude'}>,
#         <AxesSubplot:title={'center':'price'}>]], dtype=object)

# %%
# plotting the area plot
dataset['price'].plot.area(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
hist_plot.plot.area()
# Out:
# <AxesSubplot:>

# %%
# importing the module
import numpy as np

# creating a dataset
df = pd.DataFrame(np.random.rand(20, 5), columns=['A', 'B', 'C', 'D', 'E'])

# plotting area plot
df.plot.area(figsize=(10,6))
# Out:
# <AxesSubplot:>

# %%
# plotting area plot
df.plot.area(figsize=(10,6), stacked=False)
# Out:
# <AxesSubplot:>

# %%
# plotting the scatter plot
data.plot.scatter(x='price', y='area', figsize=(10, 6), c='m')

# %%
# creating sctter plot
ax=data.plot.scatter(x="price", y="area", color="m", marker="*", s=50, figsize=(10, 6))

# adding one more scattered plot on the same graph
data.plot.scatter(x="price", y="latitude", color="g", s=100, ax=ax)
# Out:
# <AxesSubplot:xlabel='price', ylabel='latitude'>

# %%
# plotting the scatter plot based on coloring
data.plot.scatter(x="area", y="price", c='floor', s=100, figsize=(10, 6))
# Out:
# <AxesSubplot:xlabel='area', ylabel='price'>

# %%
# plotting the box plot
data['price'].plot.box(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
# plotting the box plot
data.drop('price', axis=1).plot.box(figsize=(10, 6))
# Out:
# <AxesSubplot:>

# %%
# plotting a pie chart
dataset['floor'].plot.pie(figsize=(10, 6))
# Out:
# <AxesSubplot:ylabel='floor'>

# %%
#creating a DataFrame
Data = pd.DataFrame(np.random.rand(6, 3),
                   columns=('A', 'B', 'C'))

# plottig subplots
Data.plot.pie(subplots=True, figsize=(10, 6))
# Out:
# array([<AxesSubplot:ylabel='A'>, <AxesSubplot:ylabel='B'>,
#        <AxesSubplot:ylabel='C'>], dtype=object)
